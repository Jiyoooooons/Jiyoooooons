# %%
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv("C:/Users/LG GRAM/Desktop/23-1/23-1 DScover/DATA VIZ/biman.csv")

# %%
dataset.columns
# Out:
# Index(['자치구별(1)', '건강형태별(1)', '건강형태별(2)', '2021'], dtype='object')

# %%
dataset.head(10)
# Out:
#   자치구별(1)          건강형태별(1)         건강형태별(2)  2021
# 0     서울시                흡연            현재흡연율  14.9
# 1     서울시                흡연     현재흡연자의 금연시도율  45.4
# 2     서울시                음주            월간음주율  50.9
# 3     서울시                음주    연간음주자의 고위험음주율  12.5
# 4     서울시              신체활동            걷기실천율  55.8
# 5     서울시              신체활동  증등도 이상 신체활동 실천율  18.3
# 6     서울시               비만율               소계  28.6
# 7     서울시              정신건강         스트레스 인지율  26.3
# 8     서울시              정신건강          우울감 경험률   7.0
# 9     서울시  양호한 주관적 건강수준 인지율               소계  50.1

# %%
dataset.rename(columns={'자치구별(1)':'Region'},inplace=True)

# %%
dataset.rename(columns={'건강형태별(1)':'Health'},inplace=True)
dataset=dataset[['Region','Health','2021']]
dataset
# Out:
#     Region            Health  2021
# 0      서울시                흡연  14.9
# 1      서울시                흡연  45.4
# 2      서울시                음주  50.9
# 3      서울시                음주  12.5
# 4      서울시              신체활동  55.8
# ..     ...               ...   ...
# 255    강동구              신체활동  22.7
# 256    강동구               비만율  27.1
# 257    강동구              정신건강  21.5
# 258    강동구              정신건강   6.4
# 259    강동구  양호한 주관적 건강수준 인지율  51.8
#
# [260 rows x 3 columns]

# %%
df_biman = dataset[dataset['Health'].str.contains('비만율')]
df_biman.index = range(len(df_biman))
df_biman.rename(columns={'2021':'Obesity Rate'},inplace=True)
df_biman=df_biman[['Region','Obesity Rate']]
df_biman=df_biman.sort_values('Obesity Rate',ascending=True)
df_biman
# Out:
# C:\Users\LG GRAM\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    Region  Obesity Rate
# 23    강남구          22.5
# 22    서초구          23.5
# 1     종로구          25.4
# 14    마포구          25.8
# 3     용산구          26.2
# 4     성동구          26.3
# 25    강동구          27.1
# 2      중구          27.2
# 24    송파구          27.2
# 5     광진구          27.6
# 19   영등포구          28.0
# 17    구로구          28.0
# 8     성북구          28.2
# 0     서울시          28.6
# 20    동작구          28.8
# 11    노원구          28.9
# 21    관악구          29.5
# 16    강서구          29.6
# 12    은평구          29.7
# 7     중랑구          31.0
# 6    동대문구          31.3
# 13   서대문구          32.0
# 9     강북구          32.3
# 15    양천구          33.2
# 10    도봉구          33.6
# 18    금천구          34.9

# %%
df_biman.replace(to_replace={'Region':{'종로구':'Jongno-gu','중구':'Jung-gu','강남구':'Gangnam-gu','서초구':'Seocho-gu',
                                      
                                      '마포구':'Mapo-gu','용산구':'Yongsan-gu','성동구':'Seongdong-gu','강동구':'Gangdong-gu',
                                      '송파구':'Songpa-gu','광진구':'Gwangjin-gu','영등포구':'Yeongdeungpo-gu','구로구':'Guro-gu',
                                      '성북구':'Seongbuk-gu','서울시':'Seoul','동작구':'Dongjak-gu','노원구':'Nowon-gu',
                                      '관악구':'Nowon-gu','강서구':'Gangseo-gu','은평구':'Eunpyeong-gu','중랑구':'Eunpyeong-gu',
                                      '동대문구':'Dongdaemun-gu','서대문구':'Seodaemun-gu','강북구':'Gangbuk-gu','양천구':'Yangcheon-gu',
                                      '도봉구':'Dobong-gu','금천구':'Geumcheon-gu'}},inplace=True)
df_biman
# Out:
#              Region  Obesity Rate
# 23       Gangnam-gu          22.5
# 22        Seocho-gu          23.5
# 1         Jongno-gu          25.4
# 14          Mapo-gu          25.8
# 3        Yongsan-gu          26.2
# 4      Seongdong-gu          26.3
# 25      Gangdong-gu          27.1
# 2           Jung-gu          27.2
# 24        Songpa-gu          27.2
# 5       Gwangjin-gu          27.6
# 19  Yeongdeungpo-gu          28.0
# 17          Guro-gu          28.0
# 8       Seongbuk-gu          28.2
# 0             Seoul          28.6
# 20       Dongjak-gu          28.8
# 11         Nowon-gu          28.9
# 21         Nowon-gu          29.5
# 16       Gangseo-gu          29.6
# 12     Eunpyeong-gu          29.7
# 7      Eunpyeong-gu          31.0
# 6     Dongdaemun-gu          31.3
# 13     Seodaemun-gu          32.0
# 9        Gangbuk-gu          32.3
# 15     Yangcheon-gu          33.2
# 10        Dobong-gu          33.6
# 18     Geumcheon-gu          34.9

# %%
df_biman.dtypes
# Out:
# Region           object
# Obesity Rate    float64
# dtype: object

# %%
df_biman.plot.barh(x='Region',title='Obesity Rate',fontsize=15, rot=0,figsize=(20,10),alpha=0.7,width=0.7,color='green')
# Out:
# <AxesSubplot:title={'center':'Obesity Rate'}, ylabel='Region'>
