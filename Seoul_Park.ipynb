# %%
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv("C:/Users/LG GRAM/Desktop/23-1/23-1 DScover/DATA VIZ/seoul_park_1.csv",encoding='cp949')

# %%
dataset.head(10)
# Out:
#    자치구별(1)       자치구별(2)      2021 2021.1     2021.2    2021.3    2021.4  \
# 0  자치구별(1)       자치구별(2)        합계     합계         합계  자연공원(국립)  자연공원(국립)
# 1  자치구별(1)       자치구별(2)        소계     소계         소계        소계        소계
# 2  자치구별(1)       자치구별(2)        소계     소계         소계        소계        소계
# 3  자치구별(1)       자치구별(2)  공원수 (개소)   (중복)    면적 (천㎡)  공원수 (개소)      (중복)
# 4       합계         Total     2,959     53  172,675.1         1         5
# 5      NaN     Jongno-gu       104      5   11,404.1         -         1
# 6      NaN       Jung-gu        76      3    3,178.2         -         -
# 7      NaN    Yongsan-gu       108      3    1,775.5         -         -
# 8      NaN  Seongdong-gu        88      1    3,074.3         -         -
# 9      NaN   Gwangjin-gu        68      2    3,459.8         -         -
#
#      2021.5    2021.6 2021.7  ...      2021.35      2021.36      2021.37  \
# 0  자연공원(국립)      도시공원   도시공원  ...         도시공원         도시공원         도시공원
# 1        소계        소계     소계  ...  도시계획시설(공원)   도시계획시설(공원)   도시계획시설(공원)
# 2        소계        소계     소계  ...         수변공원         생태공원         생태공원
# 3   면적 (천㎡)  공원수 (개소)   (중복)  ...      면적 (천㎡)     공원수 (개소)         (중복)
# 4  37,345.0     2,296     45  ...        227.2            1            -
# 5   4,998.0        69      4  ...            -            -            -
# 6         -        61      3  ...            -            -            -
# 7         -        69      3  ...            -            -            -
# 8         -        65      1  ...            -            -            -
# 9         -        50      1  ...            -            -            -
#
#        2021.38      2021.39      2021.40      2021.41   2021.42 2021.43  \
# 0         도시공원         도시공원         도시공원         도시공원        기타      기타
# 1  도시계획시설(공원)   도시계획시설(공원)   도시계획시설(공원)   도시계획시설(공원)         소계      소계
# 2         생태공원         가로공원         가로공원         가로공원        소계      소계
# 3      면적 (천㎡)     공원수 (개소)         (중복)      면적 (천㎡)  공원수 (개소)    (중복)
# 4         51.1           10            -         27.9       662       3
# 5            -            -            -            -        35       -
# 6            -            -            -            -        15       -
# 7            -            2            -          3.5        39       -
# 8            -            3            -          8.8        23       -
# 9            -            -            -            -        18       1
#
#     2021.44
# 0        기타
# 1        소계
# 2        소계
# 3   면적 (천㎡)
# 4  16,053.3
# 5     123.6
# 6      87.3
# 7   1,016.4
# 8   1,843.3
# 9     465.9
#
# [10 rows x 47 columns]

# %%
dataset.rename(columns={'자치구별(2)':'Region'},inplace=True)
dataset
# Out:
#     자치구별(1)           Region      2021 2021.1     2021.2    2021.3    2021.4  \
# 0   자치구별(1)          자치구별(2)        합계     합계         합계  자연공원(국립)  자연공원(국립)
# 1   자치구별(1)          자치구별(2)        소계     소계         소계        소계        소계
# 2   자치구별(1)          자치구별(2)        소계     소계         소계        소계        소계
# 3   자치구별(1)          자치구별(2)  공원수 (개소)   (중복)    면적 (천㎡)  공원수 (개소)      (중복)
# 4        합계            Total     2,959     53  172,675.1         1         5
# 5       NaN        Jongno-gu       104      5   11,404.1         -         1
# 6       NaN          Jung-gu        76      3    3,178.2         -         -
# 7       NaN       Yongsan-gu       108      3    1,775.5         -         -
# 8       NaN     Seongdong-gu        88      1    3,074.3         -         -
# 9       NaN      Gwangjin-gu        68      2    3,459.8         -         -
# 10      NaN    Dongdaemun-gu        92      2    1,216.0         -         -
# 11      NaN      Jungnang-gu       109      1    5,233.0         -         -
# 12      NaN      Seongbuk-gu       122      9    8,491.6         -         1
# 13      NaN       Gangbuk-gu        84      1   14,383.6         1         -
# 14      NaN        Dobong-gu        80      2   10,160.4         -         1
# 15      NaN         Nowon-gu       190      1   14,742.9         -         -
# 16      NaN     Eunpyeong-gu       136      5   14,368.2         -         1
# 17      NaN     Seodaemun-gu       124      5    5,098.9         -         1
# 18      NaN          Mapo-gu       144      -    4,570.8         -         -
# 19      NaN     Yangcheon-gu       123      1    3,049.6         -         -
# 20      NaN       Gangseo-gu       173      -    4,518.3         -         -
# 21      NaN          Guro-gu       108      2    3,641.4         -         -
# 22      NaN     Geumcheon-gu        55      2    2,774.4         -         -
# 23      NaN  Yeongdeungpo-gu       108      -    3,009.1         -         -
# 24      NaN       Dongjak-gu        86      1    4,327.3         -         -
# 25      NaN        Gwanak-gu       134      3   12,485.0         -         -
# 26      NaN        Seocho-gu       179      1   15,072.0         -         -
# 27      NaN       Gangnam-gu       164      1    7,791.3         -         -
# 28      NaN        Songpa-gu       174      1    4,771.4         -         -
# 29      NaN      Gangdong-gu       129      1    3,407.7         -         -
# 30      NaN            서울대공원         1      -    6,670.0         -         -
#
#       2021.5    2021.6 2021.7  ...      2021.35      2021.36      2021.37  \
# 0   자연공원(국립)      도시공원   도시공원  ...         도시공원         도시공원         도시공원
# 1         소계        소계     소계  ...  도시계획시설(공원)   도시계획시설(공원)   도시계획시설(공원)
# 2         소계        소계     소계  ...         수변공원         생태공원         생태공원
# 3    면적 (천㎡)  공원수 (개소)   (중복)  ...      면적 (천㎡)     공원수 (개소)         (중복)
# 4   37,345.0     2,296     45  ...        227.2            1            -
# 5    4,998.0        69      4  ...            -            -            -
# 6          -        61      3  ...            -            -            -
# 7          -        69      3  ...            -            -            -
# 8          -        65      1  ...            -            -            -
# 9          -        50      1  ...            -            -            -
# 10         -        76      2  ...            -            -            -
# 11         -        72      1  ...            -            -            -
# 12   3,864.0        79      8  ...          1.8            -            -
# 13  11,899.0        64      1  ...            -            -            -
# 14   8,703.0        52      1  ...            -            1            -
# 15         -       138      1  ...            -            -            -
# 16   7,663.0       103      4  ...            -            -            -
# 17     218.0        83      4  ...            -            -            -
# 18         -       101      -  ...            -            -            -
# 19         -       105      1  ...            -            -            -
# 20         -       161      -  ...            -            -            -
# 21         -        68      2  ...            -            -            -
# 22         -        47      2  ...            -            -            -
# 23         -        75      -  ...            -            -            -
# 24         -        70      -  ...            -            -            -
# 25         -       101      3  ...         33.5            -            -
# 26         -       154      1  ...        132.1            -            -
# 27         -       151      1  ...         14.1            -            -
# 28         -       161      -  ...          4.3            -            -
# 29         -       120      1  ...         41.5            -            -
# 30         -         1      -  ...            -            -            -
#
#         2021.38      2021.39      2021.40      2021.41   2021.42 2021.43  \
# 0          도시공원         도시공원         도시공원         도시공원        기타      기타
# 1   도시계획시설(공원)   도시계획시설(공원)   도시계획시설(공원)   도시계획시설(공원)         소계      소계
# 2          생태공원         가로공원         가로공원         가로공원        소계      소계
# 3       면적 (천㎡)     공원수 (개소)         (중복)      면적 (천㎡)  공원수 (개소)    (중복)
# 4          51.1           10            -         27.9       662       3
# 5             -            -            -            -        35       -
# 6             -            -            -            -        15       -
# 7             -            2            -          3.5        39       -
# 8             -            3            -          8.8        23       -
# 9             -            -            -            -        18       1
# 10            -            2            -          5.8        16       -
# 11            -            -            -            -        37       -
# 12            -            -            -            -        43       -
# 13            -            -            -            -        19       -
# 14         51.1            -            -            -        28       -
# 15            -            -            -            -        52       -
# 16            -            -            -            -        33       -
# 17            -            -            -            -        41       -
# 18            -            -            -            -        43       -
# 19            -            -            -            -        18       -
# 20            -            1            -          2.6        12       -
# 21            -            2            -          7.2        40       -
# 22            -            -            -            -         8       -
# 23            -            -            -            -        33       -
# 24            -            -            -            -        16       1
# 25            -            -            -            -        33       -
# 26            -            -            -            -        25       -
# 27            -            -            -            -        13       -
# 28            -            -            -            -        13       1
# 29            -            -            -            -         9       -
# 30            -            -            -            -         -       -
#
#      2021.44
# 0         기타
# 1         소계
# 2         소계
# 3    면적 (천㎡)
# 4   16,053.3
# 5      123.6
# 6       87.3
# 7    1,016.4
# 8    1,843.3
# 9      465.9
# 10     241.1
# 11     182.7
# 12      53.0
# 13     114.4
# 14     207.2
# 15     335.1
# 16     105.2
# 17      20.5
# 18   1,313.0
# 19     422.6
# 20   1,084.4
# 21     321.7
# 22     164.0
# 23   2,344.6
# 24     236.2
# 25      60.6
# 26     804.3
# 27   1,289.7
# 28   2,674.3
# 29     542.2
# 30         -
#
# [31 rows x 47 columns]

# %%
df=dataset[['Region','2021','2021.1']]
df
# Out:
#              Region      2021 2021.1
# 0           자치구별(2)        합계     합계
# 1           자치구별(2)        소계     소계
# 2           자치구별(2)        소계     소계
# 3           자치구별(2)  공원수 (개소)   (중복)
# 4             Total     2,959     53
# 5         Jongno-gu       104      5
# 6           Jung-gu        76      3
# 7        Yongsan-gu       108      3
# 8      Seongdong-gu        88      1
# 9       Gwangjin-gu        68      2
# 10    Dongdaemun-gu        92      2
# 11      Jungnang-gu       109      1
# 12      Seongbuk-gu       122      9
# 13       Gangbuk-gu        84      1
# 14        Dobong-gu        80      2
# 15         Nowon-gu       190      1
# 16     Eunpyeong-gu       136      5
# 17     Seodaemun-gu       124      5
# 18          Mapo-gu       144      -
# 19     Yangcheon-gu       123      1
# 20       Gangseo-gu       173      -
# 21          Guro-gu       108      2
# 22     Geumcheon-gu        55      2
# 23  Yeongdeungpo-gu       108      -
# 24       Dongjak-gu        86      1
# 25        Gwanak-gu       134      3
# 26        Seocho-gu       179      1
# 27       Gangnam-gu       164      1
# 28        Songpa-gu       174      1
# 29      Gangdong-gu       129      1
# 30            서울대공원         1      -

# %%
df1=df.iloc[4:,:]
df1.index = range(len(df1))
df1
# Out:
#              Region   2021 2021.1
# 0             Total  2,959     53
# 1         Jongno-gu    104      5
# 2           Jung-gu     76      3
# 3        Yongsan-gu    108      3
# 4      Seongdong-gu     88      1
# 5       Gwangjin-gu     68      2
# 6     Dongdaemun-gu     92      2
# 7       Jungnang-gu    109      1
# 8       Seongbuk-gu    122      9
# 9        Gangbuk-gu     84      1
# 10        Dobong-gu     80      2
# 11         Nowon-gu    190      1
# 12     Eunpyeong-gu    136      5
# 13     Seodaemun-gu    124      5
# 14          Mapo-gu    144      -
# 15     Yangcheon-gu    123      1
# 16       Gangseo-gu    173      -
# 17          Guro-gu    108      2
# 18     Geumcheon-gu     55      2
# 19  Yeongdeungpo-gu    108      -
# 20       Dongjak-gu     86      1
# 21        Gwanak-gu    134      3
# 22        Seocho-gu    179      1
# 23       Gangnam-gu    164      1
# 24        Songpa-gu    174      1
# 25      Gangdong-gu    129      1
# 26            서울대공원      1      -

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Region  27 non-null     object
#  1   2021    27 non-null     object
#  2   2021.1  27 non-null     object
# dtypes: object(3)
# memory usage: 776.0+ bytes

# %%
df1=df1.replace('2,959','2959')
df1=df1.astype({'2021':'int'})

# %%
df1.dtypes
# Out:
# Region    object
# 2021       int32
# 2021.1    object
# dtype: object

# %%
df1=df1.replace('-','0')
df1=df1.astype({'2021.1':'int'})
df1.dtypes
# Out:
# Region    object
# 2021       int32
# 2021.1     int32
# dtype: object

# %%
#소계-중복
df1['nettotal']=(df1['2021']-df1['2021.1'])
df1
# Out:
#              Region  2021  2021.1  nettotal
# 0             Total  2959      53      2906
# 1         Jongno-gu   104       5        99
# 2           Jung-gu    76       3        73
# 3        Yongsan-gu   108       3       105
# 4      Seongdong-gu    88       1        87
# 5       Gwangjin-gu    68       2        66
# 6     Dongdaemun-gu    92       2        90
# 7       Jungnang-gu   109       1       108
# 8       Seongbuk-gu   122       9       113
# 9        Gangbuk-gu    84       1        83
# 10        Dobong-gu    80       2        78
# 11         Nowon-gu   190       1       189
# 12     Eunpyeong-gu   136       5       131
# 13     Seodaemun-gu   124       5       119
# 14          Mapo-gu   144       0       144
# 15     Yangcheon-gu   123       1       122
# 16       Gangseo-gu   173       0       173
# 17          Guro-gu   108       2       106
# 18     Geumcheon-gu    55       2        53
# 19  Yeongdeungpo-gu   108       0       108
# 20       Dongjak-gu    86       1        85
# 21        Gwanak-gu   134       3       131
# 22        Seocho-gu   179       1       178
# 23       Gangnam-gu   164       1       163
# 24        Songpa-gu   174       1       173
# 25      Gangdong-gu   129       1       128
# 26            서울대공원     1       0         1

# %%
df2=df1[['Region','nettotal']]
df2=df2.loc[1:25,:] #소계, 마지막 서울대공원 빼기
df2
# Out:
#              Region  nettotal
# 1         Jongno-gu        99
# 2           Jung-gu        73
# 3        Yongsan-gu       105
# 4      Seongdong-gu        87
# 5       Gwangjin-gu        66
# 6     Dongdaemun-gu        90
# 7       Jungnang-gu       108
# 8       Seongbuk-gu       113
# 9        Gangbuk-gu        83
# 10        Dobong-gu        78
# 11         Nowon-gu       189
# 12     Eunpyeong-gu       131
# 13     Seodaemun-gu       119
# 14          Mapo-gu       144
# 15     Yangcheon-gu       122
# 16       Gangseo-gu       173
# 17          Guro-gu       106
# 18     Geumcheon-gu        53
# 19  Yeongdeungpo-gu       108
# 20       Dongjak-gu        85
# 21        Gwanak-gu       131
# 22        Seocho-gu       178
# 23       Gangnam-gu       163
# 24        Songpa-gu       173
# 25      Gangdong-gu       128

# %%
df3=df2.sort_values('nettotal',ascending=True)
df3
# Out:
#              Region  nettotal
# 18     Geumcheon-gu        53
# 5       Gwangjin-gu        66
# 2           Jung-gu        73
# 10        Dobong-gu        78
# 9        Gangbuk-gu        83
# 20       Dongjak-gu        85
# 4      Seongdong-gu        87
# 6     Dongdaemun-gu        90
# 1         Jongno-gu        99
# 3        Yongsan-gu       105
# 17          Guro-gu       106
# 7       Jungnang-gu       108
# 19  Yeongdeungpo-gu       108
# 8       Seongbuk-gu       113
# 13     Seodaemun-gu       119
# 15     Yangcheon-gu       122
# 25      Gangdong-gu       128
# 12     Eunpyeong-gu       131
# 21        Gwanak-gu       131
# 14          Mapo-gu       144
# 23       Gangnam-gu       163
# 16       Gangseo-gu       173
# 24        Songpa-gu       173
# 22        Seocho-gu       178
# 11         Nowon-gu       189

# %%
sns.barplot(data=df3,x='Region',y='nettotal') #barplot 오류
# Out:
# <AxesSubplot:xlabel='Region', ylabel='nettotal'>

# %%
df3.dtypes
# Out:
# Region      object
# nettotal     int32
# dtype: object

# %%
df3.rename(columns={'nettotal':'Num_of_parks'},inplace=True)
df3.plot.barh(x='Region',title='Num_of_parks',fontsize=15, rot=0,figsize=(20,10),alpha=0.7,width=0.7)
# Out:
# <AxesSubplot:title={'center':'Num_of_parks'}, ylabel='Region'>
