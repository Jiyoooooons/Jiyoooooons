# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:/Users/LG GRAM/Desktop/23-1/23-1 DScover/DATA VIZ/Seoul_Park_final.csv")

# %%
df1=df1[['Region','Num_of_parks']]
df1
# Out:
#              Region  Num_of_parks
# 3         Dobong-gu            78
# 7     Dongdaemun-gu            90
# 5        Dongjak-gu            85
# 17     Eunpyeong-gu           131
# 4        Gangbuk-gu            83
# 16      Gangdong-gu           128
# 20       Gangnam-gu           163
# 21       Gangseo-gu           173
# 0      Geumcheon-gu            53
# 10          Guro-gu           106
# 18        Gwanak-gu           131
# 1       Gwangjin-gu            66
# 8         Jongno-gu            99
# 2           Jung-gu            73
# 11      Jungnang-gu           108
# 19          Mapo-gu           144
# 24         Nowon-gu           189
# 23        Seocho-gu           178
# 14     Seodaemun-gu           119
# 13      Seongbuk-gu           113
# 6      Seongdong-gu            87
# 22        Songpa-gu           173
# 15     Yangcheon-gu           122
# 12  Yeongdeungpo-gu           108
# 9        Yongsan-gu           105

# %%
df1=df1.sort_values('Region',ascending=True)
df1.index = range(len(df1))
df1
# Out:
#              Region  Num_of_parks
# 0         Dobong-gu            78
# 1     Dongdaemun-gu            90
# 2        Dongjak-gu            85
# 3      Eunpyeong-gu           131
# 4        Gangbuk-gu            83
# 5       Gangdong-gu           128
# 6        Gangnam-gu           163
# 7        Gangseo-gu           173
# 8      Geumcheon-gu            53
# 9           Guro-gu           106
# 10        Gwanak-gu           131
# 11      Gwangjin-gu            66
# 12        Jongno-gu            99
# 13          Jung-gu            73
# 14      Jungnang-gu           108
# 15          Mapo-gu           144
# 16         Nowon-gu           189
# 17        Seocho-gu           178
# 18     Seodaemun-gu           119
# 19      Seongbuk-gu           113
# 20     Seongdong-gu            87
# 21        Songpa-gu           173
# 22     Yangcheon-gu           122
# 23  Yeongdeungpo-gu           108
# 24       Yongsan-gu           105

# %%
df2 = pd.read_csv("C:/Users/LG GRAM/Desktop/23-1/23-1 DScover/DATA VIZ/Obesity Rate_final.csv")

# %%
df2=df2.sort_values('Region',ascending=True)
df2=df2[['Region','Obesity Rate']]
df2=df2.sort_values('Region',ascending=True)
df2.index = range(len(df2))
df2.rename(columns={'Region':'Region2'},inplace=True)
df2
# Out:
#             Region2  Obesity Rate
# 0         Dobong-gu          33.6
# 1     Dongdaemun-gu          31.3
# 2        Dongjak-gu          28.8
# 3      Eunpyeong-gu          31.0
# 4      Eunpyeong-gu          29.7
# 5        Gangbuk-gu          32.3
# 6       Gangdong-gu          27.1
# 7        Gangnam-gu          22.5
# 8        Gangseo-gu          29.6
# 9      Geumcheon-gu          34.9
# 10          Guro-gu          28.0
# 11      Gwangjin-gu          27.6
# 12        Jongno-gu          25.4
# 13          Jung-gu          27.2
# 14          Mapo-gu          25.8
# 15         Nowon-gu          28.9
# 16         Nowon-gu          29.5
# 17        Seocho-gu          23.5
# 18     Seodaemun-gu          32.0
# 19      Seongbuk-gu          28.2
# 20     Seongdong-gu          26.3
# 21            Seoul          28.6
# 22        Songpa-gu          27.2
# 23     Yangcheon-gu          33.2
# 24  Yeongdeungpo-gu          28.0
# 25       Yongsan-gu          26.2

# %%
df3 = pd.read_csv("C:/Users/LG GRAM/Desktop/23-1/23-1 DScover/DATA VIZ/Hypertension_final.csv")

# %%
df3=df3.sort_values('Region',ascending=True)
df3=df3[['Region','Hypertension']]
df3=df3.sort_values('Region',ascending=True)
df3.index = range(len(df3))
df3.rename(columns={'Region':'Region3'},inplace=True)
df3
# Out:
#             Region3  Hypertension
# 0         Dobong-gu          29.3
# 1     Dongdaemun-gu          28.1
# 2        Dongjak-gu          20.8
# 3      Eunpyeong-gu          26.6
# 4        Gangbuk-gu          27.8
# 5       Gangdong-gu          21.7
# 6        Gangnam-gu          16.4
# 7        Gangseo-gu          23.5
# 8      Geumcheon-gu          30.3
# 9           Guro-gu          27.1
# 10        Gwanak-gu          23.9
# 11      Gwangjin-gu          23.8
# 12        Jongno-gu          29.3
# 13          Jung-gu          23.1
# 14      Jungnang-gu          26.9
# 15          Mapo-gu          20.3
# 16         Nowon-gu          26.5
# 17        Seocho-gu          20.2
# 18     Seodaemun-gu          27.2
# 19      Seongbuk-gu          26.9
# 20     Seongdong-gu          26.4
# 21        Songpa-gu          18.8
# 22            Total          24.0
# 23     Yangcheon-gu          22.5
# 24  Yeongdeungpo-gu          20.8
# 25       Yongsan-gu          27.1

# %%
df4 = pd.read_csv("C:/Users/LG GRAM/Desktop/23-1/23-1 DScover/DATA VIZ/Diabetes_final.csv")

# %%
df4
# Out:
#     Unnamed: 0           Region  Diabetes
# 0           23       Gangnam-gu       7.0
# 1           22        Seocho-gu       7.5
# 2            4     Seongdong-gu       9.2
# 3           14          Mapo-gu       9.2
# 4           19  Yeongdeungpo-gu       9.3
# 5           15     Yangcheon-gu       9.3
# 6           24        Songpa-gu       9.3
# 7           20       Dongjak-gu       9.4
# 8           25      Gangdong-gu       9.6
# 9            9       Gangbuk-gu       9.6
# 10          16       Gangseo-gu       9.7
# 11          11         Nowon-gu       9.8
# 12           2          Jung-gu      10.0
# 13           0            Total      10.1
# 14           5      Gwangjin-gu      10.1
# 15          21        Gwanak-gu      10.2
# 16           3       Yongsan-gu      10.6
# 17          12     Eunpyeong-gu      10.9
# 18          17          Guro-gu      11.0
# 19           8      Seongbuk-gu      11.3
# 20          13     Seodaemun-gu      11.7
# 21           7      Jungnang-gu      12.3
# 22          18     Geumcheon-gu      12.4
# 23          10        Dobong-gu      12.9
# 24           1        Jongno-gu      12.9
# 25           6    Dongdaemun-gu      13.3

# %%
df4=df4.sort_values('Region',ascending=True)
df4=df4[['Region','Diabetes']]
df4=df4.sort_values('Region',ascending=True)
df4.index = range(len(df4))
df4.rename(columns={'Region':'Region4'},inplace=True)
df4
# Out:
#             Region4  Diabetes
# 0         Dobong-gu      12.9
# 1     Dongdaemun-gu      13.3
# 2        Dongjak-gu       9.4
# 3      Eunpyeong-gu      10.9
# 4        Gangbuk-gu       9.6
# 5       Gangdong-gu       9.6
# 6        Gangnam-gu       7.0
# 7        Gangseo-gu       9.7
# 8      Geumcheon-gu      12.4
# 9           Guro-gu      11.0
# 10        Gwanak-gu      10.2
# 11      Gwangjin-gu      10.1
# 12        Jongno-gu      12.9
# 13          Jung-gu      10.0
# 14      Jungnang-gu      12.3
# 15          Mapo-gu       9.2
# 16         Nowon-gu       9.8
# 17        Seocho-gu       7.5
# 18     Seodaemun-gu      11.7
# 19      Seongbuk-gu      11.3
# 20     Seongdong-gu       9.2
# 21        Songpa-gu       9.3
# 22            Total      10.1
# 23     Yangcheon-gu       9.3
# 24  Yeongdeungpo-gu       9.3
# 25       Yongsan-gu      10.6

# %%
df12=pd.concat([df1,df2,df3,df4],axis=1)
df12=df12[['Region','Num_of_parks','Obesity Rate','Hypertension','Diabetes']]
df12= df12.set_index("Region")
df12.rename(columns={'Obesity Rate':'Obesity_Rate'},inplace=True)
df112=df12.dropna()

# %%
df112
# Out:
#                  Num_of_parks  Obesity_Rate  Hypertension  Diabetes
# Region
# Dobong-gu                78.0          33.6          29.3      12.9
# Dongdaemun-gu            90.0          31.3          28.1      13.3
# Dongjak-gu               85.0          28.8          20.8       9.4
# Eunpyeong-gu            131.0          31.0          26.6      10.9
# Gangbuk-gu               83.0          29.7          27.8       9.6
# Gangdong-gu             128.0          32.3          21.7       9.6
# Gangnam-gu              163.0          27.1          16.4       7.0
# Gangseo-gu              173.0          22.5          23.5       9.7
# Geumcheon-gu             53.0          29.6          30.3      12.4
# Guro-gu                 106.0          34.9          27.1      11.0
# Gwanak-gu               131.0          28.0          23.9      10.2
# Gwangjin-gu              66.0          27.6          23.8      10.1
# Jongno-gu                99.0          25.4          29.3      12.9
# Jung-gu                  73.0          27.2          23.1      10.0
# Jungnang-gu             108.0          25.8          26.9      12.3
# Mapo-gu                 144.0          28.9          20.3       9.2
# Nowon-gu                189.0          29.5          26.5       9.8
# Seocho-gu               178.0          23.5          20.2       7.5
# Seodaemun-gu            119.0          32.0          27.2      11.7
# Seongbuk-gu             113.0          28.2          26.9      11.3
# Seongdong-gu             87.0          26.3          26.4       9.2
# Songpa-gu               173.0          28.6          18.8       9.3
# Yangcheon-gu            122.0          27.2          24.0      10.1
# Yeongdeungpo-gu         108.0          33.2          22.5       9.3
# Yongsan-gu              105.0          28.0          20.8       9.3

# %%
import scipy.stats as stats

# %%
x=df112.Num_of_parks.values
y=df112.Obesity_Rate.values
stats.pearsonr(x,y) #공원개수와 비만율 관계 없음, p>0.05
# Out:
# (-0.2921906903510118, 0.15639289087126604)

# %%
import seaborn as sns
sns.regplot(df112['Num_of_parks'], df112['Obesity_Rate'], fit_reg=True)
# Out:
# C:\Users\LG GRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Num_of_parks', ylabel='Obesity_Rate'>

# %%
x=df112.Num_of_parks.values
y=df112.Hypertension.values
stats.pearsonr(x,y) #공원개수와 고혈압 유의 관계 있음, (-) 관계, p<0.05
# Out:
# (-0.5157551885445644, 0.008317349738403382)

# %%
sns.regplot(df112['Num_of_parks'], df112['Hypertension'], fit_reg=True)
# Out:
# C:\Users\LG GRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Num_of_parks', ylabel='Hypertension'>

# %%
x=df112.Num_of_parks.values
y=df112.Diabetes.values
stats.pearsonr(x,y) #공원개수와 당뇨병 유의 관계 있음, (-) 관계, p<0.05
# Out:
# (-0.5172264574424116, 0.00810313423852747)

# %%
sns.regplot(df112['Num_of_parks'], df112['Diabetes'], fit_reg=True)
# Out:
# C:\Users\LG GRAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Num_of_parks', ylabel='Diabetes'>

# %%
df5=df112[['Num_of_parks','Obesity_Rate','Hypertension','Diabetes']] #상관관계 분석
#상관계수 행렬 : 상관계수의 절대값이 1에 가까울수록 상관관계가 크다 : sth.corr()
df5.corr().round(2)
# Out:
#               Num_of_parks  Obesity_Rate  Hypertension  Diabetes
# Num_of_parks          1.00         -0.29         -0.52     -0.52
# Obesity_Rate         -0.29          1.00          0.27      0.32
# Hypertension         -0.52          0.27          1.00      0.84
# Diabetes             -0.52          0.32          0.84      1.00

# %%
sns.heatmap(df5.corr(), annot=True, cmap='RdYlBu_r',
           vmin=-1, vmax=1)
#annot=True 각 셀에 해당값을 써넣어라
#cmap='RdYlBu_r' 셀의 색깔 red yellow blue
#vmin vmax 상관계수의 최소 최대값 설정
# Out:
# <AxesSubplot:>

# %%
# 회귀분석 : 변수간 인과관계가 존재하는가? 
from statsmodels.formula.api import ols

# %%
reg1=ols('Hypertension~Num_of_parks', df5).fit()
print(reg1.summary()) #고혈압-공원 수 회귀분석
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Hypertension   R-squared:                       0.266
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     8.335
# Date:                Tue, 25 Apr 2023   Prob (F-statistic):            0.00832
# Time:                        20:59:45   Log-Likelihood:                -63.424
# No. Observations:                  25   AIC:                             130.8
# Df Residuals:                      23   BIC:                             133.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       30.3526      2.129     14.256      0.000      25.948      34.757
# Num_of_parks    -0.0505      0.017     -2.887      0.008      -0.087      -0.014
# ==============================================================================
# Omnibus:                        2.610   Durbin-Watson:                   2.359
# Prob(Omnibus):                  0.271   Jarque-Bera (JB):                1.396
# Skew:                          -0.243   Prob(JB):                        0.498
# Kurtosis:                       1.949   Cond. No.                         407.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
reg2=ols('Diabetes~Num_of_parks', df5).fit()
print(reg2.summary()) #당뇨병-공원수 회귀분석
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Diabetes   R-squared:                       0.268
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     8.400
# Date:                Tue, 25 Apr 2023   Prob (F-statistic):            0.00810
# Time:                        21:00:08   Log-Likelihood:                -42.826
# No. Observations:                  25   AIC:                             89.65
# Df Residuals:                      23   BIC:                             92.09
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       12.9029      0.934     13.814      0.000      10.971      14.835
# Num_of_parks    -0.0222      0.008     -2.898      0.008      -0.038      -0.006
# ==============================================================================
# Omnibus:                        3.988   Durbin-Watson:                   2.520
# Prob(Omnibus):                  0.136   Jarque-Bera (JB):                1.519
# Skew:                           0.095   Prob(JB):                        0.468
# Kurtosis:                       1.807   Cond. No.                         407.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.pairplot(df5[['Num_of_parks', 'Obesity_Rate', 'Hypertension', 'Diabetes']],
            kind='reg')
